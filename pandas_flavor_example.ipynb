# %% [markdown]
# Beispiel, wie man die Funktionalität versteckt.

# %%
# %matplotlib inline
import pandas as pd
import lazyplot

# %%
df = pd.read_csv('fake_umsatz_einzelposten_plz.csv', sep=';',  dayfirst=True,  dtype={1: str})

# %%
df.sample()
# Out:
#           datum    plz  gezahlt  betrag
# 87698  26.08.18  24912      1.3     0.0

# %%
df.lazyplot.date_plot(date_column='datum', values=['gezahlt', 'betrag', 'betrag2'], title='Jahresübersicht')

# %%
df.lazyplot.group_by_plz()
# Out:
#                        Ort  Longitude  Latitude   betrag
# Plz
# 18055              Rostock    54.0849  12.17030  2082.32
# 21614            Buxtehude    53.4662   9.69159  1005.65
# 23554               Lübeck    53.8920  10.67880   870.85
# 24340          Eckernförde    54.4643   9.82413  1052.27
# 24376              Kappeln    54.6753   9.94428  7336.61
# ...                    ...        ...       ...      ...
# 25923           Süderlügum    54.8630   8.89546  1107.97
# 25924  Emmelsbüll-Horsbüll    54.8527   8.67391  3332.05
# 25926             Ladelund    54.8465   9.02893   983.18
# 30855          Langenhagen    52.4734   9.69751   917.82
# 33098            Paderborn    51.7138   8.75427  1981.23
#
# [67 rows x 4 columns]

# %%
_.lazyplot.plot_to_germany()
# Out:
# 7127it [00:17, 415.57it/s]
